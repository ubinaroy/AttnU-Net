# %%
# %load_ext autoreload
# %autoreload 2

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import sys
sys.path.append('/content/drive/MyDrive/PROJs/AttU-Net')

# %%
import os
cwd = os.getcwd()
path = "/content/drive/MyDrive/PROJs/AttU-Net"
if cwd != path:
  os.chdir(path)
print(os.listdir(path))
# Out:
# ['data', 'utils', 'ui', 'model', '__pycache__', '.ipynb_checkpoints', 'model_checkpoint', 'clear.py', 'train.py', 'predict.py', 'parser.py', 'main.py', 'Cursor.ipynb']

# %%
for dirname, _, filename in os.walk('./'):
  for file in filename:
    print(os.path.join(dirname, file))
# Out:
# ./clear.py
# ./train.py
# ./predict.py
# ./parser.py
# ./main.py
# ./Cursor.ipynb
# ./data/test/26.png
# ./data/test/25.png
# ./data/test/27.png
# ./data/test/22.png
# ./data/test/17.png
# ./data/test/18.png
# ./data/test/11.png
# ./data/test/13.png
# ./data/test/15.png
# ./data/test/14.png
# ./data/test/23.png
# ./data/test/28.png
# ./data/test/24.png
# ./data/test/6.png
# ./data/test/19.png
# ./data/test/0.png
# ./data/test/29.png
# ./data/test/10.png
# ./data/test/5.png
# ./data/test/20.png
# ./data/test/2.png
# ./data/test/21.png
# ./data/test/8.png
# ./data/test/9.png
# ./data/test/1.png
# ./data/test/7.png
# ./data/test/4.png
# ./data/test/3.png
# ./data/test/16.png
# ./data/test/12.png
# ./data/train/image/18.png
# ./data/train/image/5.png
# ./data/train/image/7.png
# ./data/train/image/20.png
# ./data/train/image/28.png
# ./data/train/image/8.png
# ./data/train/image/9.png
# ./data/train/image/24.png
# ./data/train/image/16.png
# ./data/train/image/17.png
# ...

# %%
# !python3 main.py --type="train"
# Out:
# >>>>>> Data Loading...
# 数据个数： 30
#   0% 0/15 [00:00<?, ?it/s]torch.Size([2, 1, 512, 512])
#   7% 1/15 [00:01<00:26,  1.92s/it]torch.Size([2, 1, 512, 512])
#  13% 2/15 [00:03<00:24,  1.90s/it]torch.Size([2, 1, 512, 512])
#  20% 3/15 [00:05<00:23,  1.93s/it]torch.Size([2, 1, 512, 512])
#  27% 4/15 [00:08<00:22,  2.07s/it]torch.Size([2, 1, 512, 512])
#  33% 5/15 [00:11<00:25,  2.50s/it]torch.Size([2, 1, 512, 512])
#  40% 6/15 [00:13<00:22,  2.46s/it]torch.Size([2, 1, 512, 512])
#  47% 7/15 [00:15<00:18,  2.37s/it]torch.Size([2, 1, 512, 512])
#  53% 8/15 [00:17<00:15,  2.24s/it]torch.Size([2, 1, 512, 512])
#  60% 9/15 [00:20<00:13,  2.26s/it]torch.Size([2, 1, 512, 512])
#  67% 10/15 [00:22<00:11,  2.40s/it]torch.Size([2, 1, 512, 512])
#  73% 11/15 [00:25<00:09,  2.33s/it]torch.Size([2, 1, 512, 512])
#  80% 12/15 [00:27<00:06,  2.31s/it]torch.Size([2, 1, 512, 512])
#  87% 13/15 [00:29<00:04,  2.37s/it]torch.Size([2, 1, 512, 512])
# ...

# %%
! python3 main.py --type="predict"

# %%
# 为什么要 Clear？
# ——> Clear 已经 pred 生成的图像

# !python3 clear.py
